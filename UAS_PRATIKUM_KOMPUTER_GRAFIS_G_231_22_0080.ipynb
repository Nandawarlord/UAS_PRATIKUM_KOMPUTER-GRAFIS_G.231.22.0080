# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0431e755-8980-4021-8ab7-c99349207c1a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0431e755-8980-4021-8ab7-c99349207c1a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('stock.csv')
df
# Out:
#                     Stock Name Symbol  Shares Purchase Price  Cost Basis  \
# 0                        Apple   AAPL     100         $90.00   $9.000.00
# 1                    Microsoft   MSFT     200         $32.00   $6.400.00
# 2                   Salesforce    CRM     150         $25.00   $3.750.00
# 3                       Oracle   ORCL     250         $50.00  $12.500.00
# 4   Hewlett Packard Enterprise    HPE     500         $18.00   $9.000.00
# 5                     Alphabet   GOOG     100        $225.00  $22.500.00
# 6                        Intel   INTC     200         $22.00   $4.400.00
# 7                        Cisco   CSCO     225         $18.00   $4.050.00
# 8                     Qualcomm   QCOM     185         $65.00  $12.025.00
# 9                       Amazon   AMZN      50        $800.00  $40.000.00
# 10                      Redhat    RHT     100         $95.00   $9.500.00
# 11                    Facebook     FB    1000         $17.00  $17.000.00
# ...

# %% [markdown]
# A.) Distribusi data pada setiap atribut Purchase Price, Current Price dan Gain/Loss dengan grafik histrogram

# %%
# a.) Purchase Price
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 5))

# Mengambil data Purchase Price
plt.hist(purchase_price, bins=13,color='purple', edgecolor='white', alpha=0.9)


# Memberikan Judul, Mengubah Ukuran Font, dan Warna
plt.title('Histogram Untuk Purchase Price')
plt.xlabel('Purchase Price($)', fontsize=13)
plt.ylabel('Frequency', fontsize=15, color='red')

# Memberikan angka terbatas di sumbu -y
plt.yticks(range(1, 11))

plt.show()

# %%
# b.) Current Price
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 5))
current_price = [144.13, 65.57, 82.57, 44.56, 17.69, 833.36, 36.07, 33.24, 56.48, 897.64, 86.26, 141.64, 14.61]


# Mengambil data Current Price
plt.hist(current_price, bins=10, edgecolor='black',color='purple', alpha=0.9)


# Memberikan Judul, Mengubah Ukuran Font, dan Warna
plt.title('Histogram Untuk Current Price',color='blue')
plt.xlabel('Current Price ($)', fontsize=13)
plt.ylabel('Frekuensi', fontsize=15, color='red')

# Memberikan angka terbatas di sumbu -y
plt.yticks(range(1, 11))

plt.show()

# %%
# c.) Gain/Loss
import matplotlib.pyplot as plt
gain_loss = [14269.14, 13048.57, 12302.93, 11094.20, 8824.82, 82502.64, 7176.94, 7445.54, 10391.40, 43984.14, 8539.74, 141498.36, 7287.94]
plt.figure(figsize=(15, 5))

# Mengambil data Gain/Loss
plt.hist(gain_loss, bins=12, edgecolor='black',
         color='purple' ,alpha=0.9)

# Memberikan Judul, Mengubah Ukuran Font, dan Warna
plt.title('Histogram Untuk Gain/Loss',color='blue', fontsize=13)
plt.xlabel('Gain/Loss ($)', fontsize=13)
plt.ylabel('Frekuensi', fontsize=15, color='red')

# Memberikan angka terbatas di sumbu -y
plt.yticks(range(1, 11))

plt.show()

# %% [markdown]
# B. Atribut Stock Name dan Symbol yang memiliki Dividen / Share 5 tertinggi

# %%
#memilih data Shares tertinggi
sorted_df = df.sort_values('Dividend/share', ascending=False)
td5 = sorted_df.head(5) #td5 (Top Divident 5)

#memberi nomer urut
td5 = td5.set_index(pd.Index(range(1, len(td5)+1)))

#memberi nama tabel
result = td5[['Stock Name', 'Symbol','Dividend/share']]

#menampilkan hasil
print('Top 5 Stocks with highest Dividend/share:')
print(result)
# Out:
# Top 5 Stocks with highest Dividend/share:
#   Stock Name Symbol Dividend/share
# 1      Apple   AAPL          $2.28
# 2   Qualcomm   QCOM          $2.12
# 3  Microsoft   MSFT          $1.56
# 4      Cisco   CSCO          $1.16
# 5      Intel   INTC          $1.09

# %% [markdown]
# c. Atribut Stock Name dan Symbol yang memiliki Market Value 5 tertinggi.

# %%
#memilih data market Value
sorted_df = df.sort_values('Market Value', ascending=False).reset_index(drop=True)
top_mv = sorted_df.head(5) #mv = Market Value

#memberi nomer urut
top5MV = sorted_df.head(5)
top5MV = top5MV.set_index(pd.Index(range(1, len(top5MV)+1)))


#memberi nama tabel
hasil = top5MV[['Stock Name','Symbol','Market Value']]

print(hasil)
# Out:
#                    Stock Name Symbol Market Value
# 1                    Alphabet   GOOG   $83.336.00
# 2  Hewlett Packard Enterprise    HPE    $8.842.50
# 3                      Redhat    RHT    $8.626.00
# 4                       Cisco   CSCO    $7.478.78
# 5                     Twitter   TWTR    $7.302.55

# %% [markdown]
# d. Atribut Stock Name dan Symbol yang memiliki Annual Yield 7 tertinggi.

# %%
#memilih data Annual Yield
sorted_df = df.sort_values('Annual Yield', ascending=False)
top_ay = sorted_df.head(7) #ay = Annual Yield

#memberi nomer urut
top_ay = top_ay.set_index(pd.Index(range(1, len(top_ay)+1)))

#memberi nama tabel
result = top_ay[['Stock Name', 'Symbol','Annual Yield']]

#menampilkan hasil
print('\nTop 7 Stocks with highest Annual Yield:')
print(result)
# Out:
# Top 7 Stocks with highest Annual Yield:
#                    Stock Name Symbol Annual Yield
# 1                    Qualcomm   QCOM        3.75%
# 2                       Cisco   CSCO        3.49%
# 3                       Intel   INTC        3.02%
# 4                   Microsoft   MSFT        2.38%
# 5                       Apple   AAPL        1.58%
# 6  Hewlett Packard Enterprise    HPE        1.47%
# 7                      Oracle   ORCL        1.44%
